# %%
import os
os.chdir('../../')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import albumentations as A
from albumentations.pytorch import ToTensorV2

from datasets.small_obstacles import SmallObstacles
from easydict import EasyDict as edict

from tqdm.notebook import tqdm

# %% [markdown]
# # Dataset Test

# %%
so_config = edict(
    dataset_root='/home/user/datasets/SmallObjectsSegmentation',
)

transform_so = A.Compose([
    ToTensorV2()
])

so_dataset = SmallObstacles(so_config, transform_so, mode='val')

# %%
len(so_dataset)
# Out:
# 496

# %%
img, lbl = so_dataset[140]

plt.imshow(img.permute(1, 2, 0))
plt.show()

plt.imshow(lbl)
plt.show()

k = 1
m = lbl.clone()
m[lbl == k] = 1
m[lbl != k] = 0
plt.imshow(m)
plt.show()

# %%
img.shape, lbl.shape
# Out:
# (torch.Size([3, 720, 1280]), torch.Size([720, 1280]))

# %% [markdown]
# # Config
